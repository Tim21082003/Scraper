# %%
#pip install 'requests<2.29' 'urllib3<2' 'charset_normalizer<3'
import os
import requests
import pandas as pd
from urllib.parse import quote

# %%
csv_path = "/mmfs1/home/a.patronigranda/Documents/6043.004US1_MRR/References 6043.004US1 MRR.csv"
download_dir = "/mmfs1/home/a.patronigranda/Documents/6043.004US1_MRR"
os.makedirs(download_dir, exist_ok=True)

# %%
df = pd.read_csv(csv_path)

# %%
# Function to download a PDF using DOI via doi.org or arXiv
def try_download_pdf(url, filename):
    """Attempt to download a PDF from a direct URL"""
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = requests.get(url, headers=headers, allow_redirects=True, timeout=20)
        if 'pdf' in response.headers.get('Content-Type', '') or response.url.endswith('.pdf'):
            file_path = os.path.join(download_dir, f"{filename}.pdf")
            with open(file_path, "wb") as f:
                f.write(response.content)
            return True
    except Exception as e:
        print(f"Download error for {filename}: {e}")
    return False

def get_pdf_from_semantic_scholar(title, author=""):
    """Search Semantic Scholar for a paper by title and optionally author"""
    api_url = f"https://api.semanticscholar.org/graph/v1/paper/search?query={quote(title)}&limit=1&fields=title,authors,year,url,openAccessPdf"
    try:
        r = requests.get(api_url, timeout=10)
        if r.status_code == 200:
            data = r.json()
            if data["total"] > 0:
                paper = data["data"][0]
                pdf_url = paper.get("openAccessPdf", {}).get("url", "")
                return pdf_url
    except Exception as e:
        print(f"Semantic Scholar lookup failed: {e}")
    return None

# %%
# Counters
success = 0
failed = 0
fail_log = []

# %%
# Process each reference

for idx, row in df.iterrows():
    title = str(row.get("Title", f"paper_{idx}")).strip()
    title_safe = title[:80].replace("/", "_").replace(" ", "_")
    doi = str(row.get("DOI", "")).strip()
    url = str(row.get("Website", "")).strip()
    author = str(row.get("Authors", "")).split(",")[0]  # Use first author
    downloaded = False

    # Try DOI
    if doi:
        downloaded = try_download_pdf(f"https://doi.org/{quote(doi)}", title_safe)

    # Try URL
    if not downloaded and url.startswith("http"):
        downloaded = try_download_pdf(url, title_safe)

    # Try Semantic Scholar search
    if not downloaded:
        print(f"🔍 Searching Semantic Scholar for: {title}")
        pdf_link = get_pdf_from_semantic_scholar(title, author)
        if pdf_link:
            downloaded = try_download_pdf(pdf_link, title_safe)

    if downloaded:
        print(f"✅ Downloaded: {title}")
        success += 1
    else:
        print(f"❌ Failed: {title}")
        failed += 1
        fail_log.append(title)
# Out:
# 🔍 Searching Semantic Scholar for: Explainable Explainable Artificial Intelligence (XAI): Concepts, taxonomies, opportunities and challenges toward responsible AI,
# ✅ Downloaded: Explainable Explainable Artificial Intelligence (XAI): Concepts, taxonomies, opportunities and challenges toward responsible AI,
# 🔍 Searching Semantic Scholar for: A Particle Swarm Optimization Backtracking Technique Inspired by Science-Fiction Time Travel,
# ❌ Failed: A Particle Swarm Optimization Backtracking Technique Inspired by Science-Fiction Time Travel,
# 🔍 Searching Semantic Scholar for: A blackboard architecture for perception planning in autonomous vehicles,
# ❌ Failed: A blackboard architecture for perception planning in autonomous vehicles,
# 🔍 Searching Semantic Scholar for: Medical Expert Systems Survey,
# ❌ Failed: Medical Expert Systems Survey,
# 🔍 Searching Semantic Scholar for: Fundamentals of Expert Systems,
# ❌ Failed: Fundamentals of Expert Systems,
# 🔍 Searching Semantic Scholar for: Constructing an expert system,
# ❌ Failed: Constructing an expert system,
# 🔍 Searching Semantic Scholar for: Artificial General Intelligence: Concept, State of the Art, and Future Prospects,
# ❌ Failed: Artificial General Intelligence: Concept, State of the Art, and Future Prospects,
# 🔍 Searching Semantic Scholar for: A blackboard architecture for control,
# ❌ Failed: A blackboard architecture for control,
# 🔍 Searching Semantic Scholar for: Adaptive Gradient Descent Backpropagation for Classification of Breast Tumors in Ultrasound Imaging,
# ❌ Failed: Adaptive Gradient Descent Backpropagation for Classification of Breast Tumors in Ultrasound Imaging,
# 🔍 Searching Semantic Scholar for: Explainable Artificial Intelligence (XAI) to Enhance Trust Management in Intrusion Detection Systems Using Decision Tree Model,
# ✅ Downloaded: Explainable Artificial Intelligence (XAI) to Enhance Trust Management in Intrusion Detection Systems Using Decision Tree Model,
# 🔍 Searching Semantic Scholar for: Adaptive switching circuits,
# Download error for Adaptive_switching_circuits,: HTTPSConnectionPool(host='www.dtic.mil', port=443): Max retries exceeded with url: /dtic/tr/fulltext/u2/241531.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)')))
# ❌ Failed: Adaptive switching circuits,
# 🔍 Searching Semantic Scholar for: Adaptively Truncating Backpropagation Through Time to Control Gradient Bias,
# ❌ Failed: Adaptively Truncating Backpropagation Through Time to Control Gradient Bias,
# 🔍 Searching Semantic Scholar for: nan
# ✅ Downloaded: nan
# 🔍 Searching Semantic Scholar for: nan
# ❌ Failed: nan
# 🔍 Searching Semantic Scholar for: A fuzzy expert system for diabetes decision support application,
# ❌ Failed: A fuzzy expert system for diabetes decision support application,
# 🔍 Searching Semantic Scholar for: Learning representations by back-propagating errors,
# ❌ Failed: Learning representations by back-propagating errors,
# 🔍 Searching Semantic Scholar for: XAI-Explainable artificial intelligence,
# ✅ Downloaded: XAI-Explainable artificial intelligence,
# 🔍 Searching Semantic Scholar for: A survey: algorithms simulating bee swarm intelligence,
# ❌ Failed: A survey: algorithms simulating bee swarm intelligence,
# 🔍 Searching Semantic Scholar for: Machine Learning Methods for Histopathological Image Analysis,
# ❌ Failed: Machine Learning Methods for Histopathological Image Analysis,
# 🔍 Searching Semantic Scholar for: Methodologies from Machine Learning in Data Analysis and Software,
# ❌ Failed: Methodologies from Machine Learning in Data Analysis and Software,
# 🔍 Searching Semantic Scholar for: nan
# ❌ Failed: nan
# 🔍 Searching Semantic Scholar for: Selective Smooth Fictitious Play: An approach based on game theory for patrolling infrastructures with a multi-robot system,
# ❌ Failed: Selective Smooth Fictitious Play: An approach based on game theory for patrolling infrastructures with a multi-robot system,
# 🔍 Searching Semantic Scholar for: The perceptron: A probabilistic model for information storage and organization in the brain,
# ❌ Failed: The perceptron: A probabilistic model for information storage and organization in the brain,
# 🔍 Searching Semantic Scholar for: Expert systems in land-use planning: An overview,
# ❌ Failed: Expert systems in land-use planning: An overview,
# 🔍 Searching Semantic Scholar for: Multi-agent blackboard architecture for a mobile robot,
# ❌ Failed: Multi-agent blackboard architecture for a mobile robot,
# 🔍 Searching Semantic Scholar for: Alternative control structures for speech understanding systems,
# ❌ Failed: Alternative control structures for speech understanding systems,
# 🔍 Searching Semantic Scholar for: Machine learning techniques to examine large patient databases,
# ✅ Downloaded: Machine learning techniques to examine large patient databases,
# 🔍 Searching Semantic Scholar for: Explainable Artificial Intelligence: a Systematic Review,
# ❌ Failed: Explainable Artificial Intelligence: a Systematic Review,
# 🔍 Searching Semantic Scholar for: Gradient Descent Approach to Optimal Mode Scheduling in Hybrid Dynamical Systems,
# ❌ Failed: Gradient Descent Approach to Optimal Mode Scheduling in Hybrid Dynamical Systems,
# 🔍 Searching Semantic Scholar for: Artificial neural network application to the friction stir welding of aluminum plates,
# ❌ Failed: Artificial neural network application to the friction stir welding of aluminum plates,
# 🔍 Searching Semantic Scholar for: The intelligent water drops algorithm: a nature-inspired swarm-based optimization algorithm,
# ❌ Failed: The intelligent water drops algorithm: a nature-inspired swarm-based optimization algorithm,
# 🔍 Searching Semantic Scholar for: A parallel blackboard architecture,
# ❌ Failed: A parallel blackboard architecture,
# 🔍 Searching Semantic Scholar for: nan
# ❌ Failed: nan
# 🔍 Searching Semantic Scholar for: Artificial neural networks: fundamentals, computing, design, and application,
# ❌ Failed: Artificial neural networks: fundamentals, computing, design, and application,
# Download error for A_new_interpretation_of_the_Blackboard_architecture,: HTTPConnectionPool(host='eprints.dcs.warwick.ac.uk', port=80): Max retries exceeded with url: /1368/1/cs-rr-254.pdf. (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x15551a0dd760>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# 🔍 Searching Semantic Scholar for: A new interpretation of the Blackboard architecture,
# ❌ Failed: A new interpretation of the Blackboard architecture,
# Download error for CASSANDRA-II:_a_distributed_Blackboard_system,: HTTPConnectionPool(host='eprints.dcs.warwick.ac.uk', port=80): Max retries exceeded with url: /1210/1/cs-rr-090.pdf. (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x15551a0ddfd0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# 🔍 Searching Semantic Scholar for: CASSANDRA-II: a distributed Blackboard system,
# ❌ Failed: CASSANDRA-II: a distributed Blackboard system,
# 🔍 Searching Semantic Scholar for: Machine Learning: Algorithms, Real-World Applications and Research Directions,
# ✅ Downloaded: Machine Learning: Algorithms, Real-World Applications and Research Directions,
# 🔍 Searching Semantic Scholar for: AI-Driven Cybersecurity: An Overview, Security Intelligence Modeling and Research Directions,
# ❌ Failed: AI-Driven Cybersecurity: An Overview, Security Intelligence Modeling and Research Directions,
# 🔍 Searching Semantic Scholar for: Extensive phenotype data and machine learning in prediction of mortality in acute coronary syndrome–the MADDEC study,
# ❌ Failed: Extensive phenotype data and machine learning in prediction of mortality in acute coronary syndrome–the MADDEC study,
# 🔍 Searching Semantic Scholar for: Backpropagation is Sensitive to Initial Conditions,
# ❌ Failed: Backpropagation is Sensitive to Initial Conditions,
# 🔍 Searching Semantic Scholar for: Benefits of Gain: Speeded Learning and Minimal Hidden Layers in Back-Propagation Networks,
# ❌ Failed: Benefits of Gain: Speeded Learning and Minimal Hidden Layers in Back-Propagation Networks,
# 🔍 Searching Semantic Scholar for: Particle swarm optimization,
# ❌ Failed: Particle swarm optimization,
# 🔍 Searching Semantic Scholar for: Expert systems for agriculture,
# ❌ Failed: Expert systems for agriculture,
# 🔍 Searching Semantic Scholar for: Optimization of Fuzzy Expert Systems Using Genetic Algorithms and Neural Networks,
# ❌ Failed: Optimization of Fuzzy Expert Systems Using Genetic Algorithms and Neural Networks,
# 🔍 Searching Semantic Scholar for: Towards artificial general intelligence with hybrid Tianjic chip architecture,
# ❌ Failed: Towards artificial general intelligence with hybrid Tianjic chip architecture,
# 🔍 Searching Semantic Scholar for: Deep Learning in neural networks: An overview,
# ✅ Downloaded: Deep Learning in neural networks: An overview,
# 🔍 Searching Semantic Scholar for: A Distributed Blackboard Approach Based Upon a Boundary Node Concept,
# ❌ Failed: A Distributed Blackboard Approach Based Upon a Boundary Node Concept,
# 🔍 Searching Semantic Scholar for: A modern Blackboard Architecture implementation with external command execution capability,
# ❌ Failed: A modern Blackboard Architecture implementation with external command execution capability,
# 🔍 Searching Semantic Scholar for: AI Regulation Done Right,
# ✅ Downloaded: AI Regulation Done Right,
# 🔍 Searching Semantic Scholar for: Another Voice: New York City’s war on AI job screening could produce national harm,
# ❌ Failed: Another Voice: New York City’s war on AI job screening could produce national harm,
# 🔍 Searching Semantic Scholar for: Automating the Design and Development of Gradient Descent Trained Expert System Networks,
# ✅ Downloaded: Automating the Design and Development of Gradient Descent Trained Expert System Networks,
# 🔍 Searching Semantic Scholar for: Comparing the Effect of Pruning on a Best-Path and Naive-Approach Blackboard Solver,
# ✅ Downloaded: Comparing the Effect of Pruning on a Best-Path and Naive-Approach Blackboard Solver,
# 🔍 Searching Semantic Scholar for: Evaluation of a multi- goal solver for use in a blackboard architecture,
# ❌ Failed: Evaluation of a multi- goal solver for use in a blackboard architecture,
# 🔍 Searching Semantic Scholar for: Expert System Gradient Descent Style Training: Development of a Defensible Artificial Intelligence Technique,
# ✅ Downloaded: Expert System Gradient Descent Style Training: Development of a Defensible Artificial Intelligence Technique,
# 🔍 Searching Semantic Scholar for: Expert system gradient descent style training: Development of a defensible artificial intelligence technique,
# ❌ Failed: Expert system gradient descent style training: Development of a defensible artificial intelligence technique,
# 🔍 Searching Semantic Scholar for: Gradient descent training expert system,
# ❌ Failed: Gradient descent training expert system,
# 🔍 Searching Semantic Scholar for: Machine learning performance validation and training using a ‘perfect’ expert system,
# ❌ Failed: Machine learning performance validation and training using a ‘perfect’ expert system,
# 🔍 Searching Semantic Scholar for: Explainable AI in Industry,
# ❌ Failed: Explainable AI in Industry,
# 🔍 Searching Semantic Scholar for: Artificial Neural Network Application in the Diagnosis of Disease Conditions with Liver Ultrasound Images,
# ✅ Downloaded: Artificial Neural Network Application in the Diagnosis of Disease Conditions with Liver Ultrasound Images,
# 🔍 Searching Semantic Scholar for: Estimation of physical variables from multichannel remotely sensed imagery using a neural network: Application to rainfall estimation,
# ❌ Failed: Estimation of physical variables from multichannel remotely sensed imagery using a neural network: Application to rainfall estimation,
# 🔍 Searching Semantic Scholar for: Investigating Statistical Machine Learning as a Tool for Software Development,
# ❌ Failed: Investigating Statistical Machine Learning as a Tool for Software Development,
# 🔍 Searching Semantic Scholar for: Natural Language Processing,
# ❌ Failed: Natural Language Processing,
# 🔍 Searching Semantic Scholar for: Distributed blackboard architecture for multi-spectral image interpretation based on multi-agent system,
# ❌ Failed: Distributed blackboard architecture for multi-spectral image interpretation based on multi-agent system,
# 🔍 Searching Semantic Scholar for: Stochastic Gradient Descent Tricks,
# ❌ Failed: Stochastic Gradient Descent Tricks,
# 🔍 Searching Semantic Scholar for: Implicit Bias of Gradient Descent for Wide Two-layer Neural Networks Trained with the Logistic Loss,
# ❌ Failed: Implicit Bias of Gradient Descent for Wide Two-layer Neural Networks Trained with the Logistic Loss,
# 🔍 Searching Semantic Scholar for: The Hearsay-II speech-understanding system: Integrating knowledge to resolve uncertainty,
# ❌ Failed: The Hearsay-II speech-understanding system: Integrating knowledge to resolve uncertainty,
# 🔍 Searching Semantic Scholar for: Pruning algorithms of neural networks — a comparative study,
# ❌ Failed: Pruning algorithms of neural networks — a comparative study,
# 🔍 Searching Semantic Scholar for: Ant colony optimization theory: A survey,
# ❌ Failed: Ant colony optimization theory: A survey,
# 🔍 Searching Semantic Scholar for: An Expert System for the Prediction of Student Performance in an Initial Computer Science Course,
# ❌ Failed: An Expert System for the Prediction of Student Performance in an Initial Computer Science Course,
# 🔍 Searching Semantic Scholar for: Overcoming data scarcity with transfer learning,
# ❌ Failed: Overcoming data scarcity with transfer learning,
# 🔍 Searching Semantic Scholar for: Bio-inspired approach to learning robot motion trajectories and visual control commands,
# ❌ Failed: Bio-inspired approach to learning robot motion trajectories and visual control commands,
# 🔍 Searching Semantic Scholar for: The Application of Human Factors to the Development of Expert Systems for Advanced Cockpits,
# ❌ Failed: The Application of Human Factors to the Development of Expert Systems for Advanced Cockpits,
# 🔍 Searching Semantic Scholar for: Integrating Diverse Reasoning Methods in the BBP Blackboard Control Architecture,
# ❌ Failed: Integrating Diverse Reasoning Methods in the BBP Blackboard Control Architecture,
# 🔍 Searching Semantic Scholar for: An explainable artificial intelligence system for small-unit tactical behavior,
# ❌ Failed: An explainable artificial intelligence system for small-unit tactical behavior,
# 🔍 Searching Semantic Scholar for: A multi-strategy machine learning student modeling for intelligent tutoring systems: based on Blackboard approach,
# ❌ Failed: A multi-strategy machine learning student modeling for intelligent tutoring systems: based on Blackboard approach,
# 🔍 Searching Semantic Scholar for: A Survey on the Explainability of Supervised Machine Learning,
# ✅ Downloaded: A Survey on the Explainability of Supervised Machine Learning,
# 🔍 Searching Semantic Scholar for: Towards artificial general intelligence via a multimodal foundation model,
# ❌ Failed: Towards artificial general intelligence via a multimodal foundation model,
# 🔍 Searching Semantic Scholar for: Modeling Human Expertise in Expert Systems,
# ❌ Failed: Modeling Human Expertise in Expert Systems,
# 🔍 Searching Semantic Scholar for: Deep learning for healthcare applications based on physiological signals: A review,
# ❌ Failed: Deep learning for healthcare applications based on physiological signals: A review,
# 🔍 Searching Semantic Scholar for: State-of- the-art in artificial neural network applications: A survey,
# ✅ Downloaded: State-of- the-art in artificial neural network applications: A survey,
# 🔍 Searching Semantic Scholar for: Generalization of backpropagation with application to a recurrent gas market model,
# ❌ Failed: Generalization of backpropagation with application to a recurrent gas market model,
# 🔍 Searching Semantic Scholar for: Pruning Convolutional Neural Networks for Resource Efficient Inference,
# ❌ Failed: Pruning Convolutional Neural Networks for Resource Efficient Inference,
# 🔍 Searching Semantic Scholar for: nan
# ✅ Downloaded: nan
# 🔍 Searching Semantic Scholar for: Fraud Detection using Machine Learning and Deep Learning,
# ❌ Failed: Fraud Detection using Machine Learning and Deep Learning,
# 🔍 Searching Semantic Scholar for: Towards query-efficient black-box adversary with zeroth-order natural gradient descent,
# ❌ Failed: Towards query-efficient black-box adversary with zeroth-order natural gradient descent,
# 🔍 Searching Semantic Scholar for: A Survey on Deep Reinforcement Learning for Data Processing and Analytics,
# ✅ Downloaded: A Survey on Deep Reinforcement Learning for Data Processing and Analytics,
# 🔍 Searching Semantic Scholar for: Accelerated Backpropagation Learning: Two Optimization Methods,
# ❌ Failed: Accelerated Backpropagation Learning: Two Optimization Methods,
# 🔍 Searching Semantic Scholar for: Early Neural Network Development History: The Age of Camelot,
# ❌ Failed: Early Neural Network Development History: The Age of Camelot,
# 🔍 Searching Semantic Scholar for: Application of machine learning techniques for supply chain demand forecasting,
# ❌ Failed: Application of machine learning techniques for supply chain demand forecasting,
# 🔍 Searching Semantic Scholar for: DENDRAL: A case study of the first expert system for scientific hypothesis formation,
# ✅ Downloaded: DENDRAL: A case study of the first expert system for scientific hypothesis formation,
# 🔍 Searching Semantic Scholar for: Neural self-compressor: Collective interpretation by compressing multi-layered neural networks into non-layered networks,
# ❌ Failed: Neural self-compressor: Collective interpretation by compressing multi-layered neural networks into non-layered networks,
# 🔍 Searching Semantic Scholar for: Towards machine learning based design pattern recognition,
# ❌ Failed: Towards machine learning based design pattern recognition,
# 🔍 Searching Semantic Scholar for: Structured Pruning of Deep Convolutional Neural Networks,
# ❌ Failed: Structured Pruning of Deep Convolutional Neural Networks,
# 🔍 Searching Semantic Scholar for: On the overtraining phenomenon of backpropagation neural networks,
# ❌ Failed: On the overtraining phenomenon of backpropagation neural networks,
# 🔍 Searching Semantic Scholar for: A survey of deep learning techniques for autonomous driving,
# ✅ Downloaded: A survey of deep learning techniques for autonomous driving,
# 🔍 Searching Semantic Scholar for: Expert system methodologies and applications-a decade review from 1995 to 2004,
# ❌ Failed: Expert system methodologies and applications-a decade review from 1995 to 2004,
# 🔍 Searching Semantic Scholar for: Backpropagation and stochastic gradient descent method,
# ❌ Failed: Backpropagation and stochastic gradient descent method,
# 🔍 Searching Semantic Scholar for: Machine learning for precision medicine,
# ❌ Failed: Machine learning for precision medicine,
# 🔍 Searching Semantic Scholar for: Expert systems and GIS: An application of land suitability evaluation,
# ❌ Failed: Expert systems and GIS: An application of land suitability evaluation,
# 🔍 Searching Semantic Scholar for: Deep learning for hyperspectral image classification: An overview,
# ✅ Downloaded: Deep learning for hyperspectral image classification: An overview,
# 🔍 Searching Semantic Scholar for: An Empirical Comparison of Pattern Recognition, Neural Nets, and Machine Learning Classification Methods.
# ❌ Failed: An Empirical Comparison of Pattern Recognition, Neural Nets, and Machine Learning Classification Methods.
# 🔍 Searching Semantic Scholar for: The risks associated with Artificial General Intelligence: A systematic review,
# ❌ Failed: The risks associated with Artificial General Intelligence: A systematic review,
# 🔍 Searching Semantic Scholar for: Genetic Algorithm,
# ❌ Failed: Genetic Algorithm,
# 🔍 Searching Semantic Scholar for: Neuro-fuzzy expert systems: Relevance, features and methodologies,
# ❌ Failed: Neuro-fuzzy expert systems: Relevance, features and methodologies,
# 🔍 Searching Semantic Scholar for: An overview of gradient descent optimization algorithms,
# ❌ Failed: An overview of gradient descent optimization algorithms,
# 🔍 Searching Semantic Scholar for: Hybrid expert systems: A survey of current approaches and applications,
# ❌ Failed: Hybrid expert systems: A survey of current approaches and applications,
# 🔍 Searching Semantic Scholar for: nan
# ✅ Downloaded: nan
# 🔍 Searching Semantic Scholar for: Root mean square error (RMSE) or mean absolute error (MAE)? -Arguments against avoiding RMSE in the literature,
# ✅ Downloaded: Root mean square error (RMSE) or mean absolute error (MAE)? -Arguments against avoiding RMSE in the literature,
# 🔍 Searching Semantic Scholar for: Weapons of Math Destruction: How Big Data Increases Inequality and Threatens Democracy,
# ❌ Failed: Weapons of Math Destruction: How Big Data Increases Inequality and Threatens Democracy,
# 🔍 Searching Semantic Scholar for: Imitating the brain with neurocomputer a ‘new’ way towards artificial general intelligence,
# ✅ Downloaded: Imitating the brain with neurocomputer a ‘new’ way towards artificial general intelligence,
# 🔍 Searching Semantic Scholar for: A neural network application to subcontractor rating in construction firms,
# ❌ Failed: A neural network application to subcontractor rating in construction firms,
# 🔍 Searching Semantic Scholar for: Expert system,
# ❌ Failed: Expert system,
# 🔍 Searching Semantic Scholar for: A neural network application for bankruptcy prediction,
# ❌ Failed: A neural network application for bankruptcy prediction,
# 🔍 Searching Semantic Scholar for: Evaluating the visualization of what a deep neural network has learned,
# ✅ Downloaded: Evaluating the visualization of what a deep neural network has learned,
# 🔍 Searching Semantic Scholar for: A Survey of Machine Learning for Computer Architecture and Systems,
# ✅ Downloaded: A Survey of Machine Learning for Computer Architecture and Systems,
# 🔍 Searching Semantic Scholar for: Differentiable Forward and Backward Fixed-Point Iteration Layers,
# ✅ Downloaded: Differentiable Forward and Backward Fixed-Point Iteration Layers,
# 🔍 Searching Semantic Scholar for: A systematic review of fuzzing based on machine learning techniques,
# ✅ Downloaded: A systematic review of fuzzing based on machine learning techniques,
# 🔍 Searching Semantic Scholar for: Discriminative Deep Face Shape Model for Facial Point Detection,
# ❌ Failed: Discriminative Deep Face Shape Model for Facial Point Detection,
# 🔍 Searching Semantic Scholar for: Cooperative Q learning based on blackboard architecture,
# ❌ Failed: Cooperative Q learning based on blackboard architecture,
# 🔍 Searching Semantic Scholar for: Using a data driven approach to predict waves generated by gravity driven mass flows,
# ❌ Failed: Using a data driven approach to predict waves generated by gravity driven mass flows,
# 🔍 Searching Semantic Scholar for: Federated Variance-Reduced Stochastic Gradient Descent with Robustness to Byzantine Attacks,
# ❌ Failed: Federated Variance-Reduced Stochastic Gradient Descent with Robustness to Byzantine Attacks,
# 🔍 Searching Semantic Scholar for: Deep Learning on Graphs: A Survey,
# ✅ Downloaded: Deep Learning on Graphs: A Survey,

# %%
# Summary
print("\n=== Download Summary ===")
print(f"✅ Successful downloads: {success}")
print(f"❌ Failed downloads: {failed}")
# Out:
# === Download Summary ===
# ✅ Successful downloads: 27
# ❌ Failed downloads: 95
